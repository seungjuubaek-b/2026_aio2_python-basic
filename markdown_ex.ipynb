# %% [markdown]
# # 제목1
# ## 제목2
# ### 제목3
# #### 제목4

# %% [markdown]
# **제목**
#
# *기울임*
#
# ~~취소선~~~

# %% [markdown]
# - 순서 없는 목록
# * 순서 없는 목록
# 1. 순서 있는 목록
# 2. 순서 있는 목록

# %% [markdown]
# [네이버](https:www.naver.com)
# [다음](https:www.daum.net)

# %% [markdown]
# 'print()'
#
# ```python
# print("Hello!")
# ```

# %% [markdown]
# | 이름 | 점수 |
# |---|---:|
# | 철수 | 90 |
# | 영희 | 95 |
