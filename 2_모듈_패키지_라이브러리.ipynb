# %% [markdown]
# # 모듈 정의하기
# calc.py 모듈 만들기
# 모듈 내에 함수 정의 - add()

# %% [markdown]
# # 모듈 가져오기

# %% [markdown]
# # 모듈 단독으로 실행
#
# 터미널에서
# ```
# python calc.py
# ```
# 실행
# ```
# if __name__ '__main__' :
#     # 실행 내용을 넣어준다.
# ```

# %%
print('hello')
# Out:
# hello

# %%
import calc
calc.add(10,20)
# vscode 에서 ipynb 파일의 코드 셀에서 라인넘버 보는 단축키
# Out:
# 30

# %%
print(calc.add(10, 20))
# Out:
# 30

# %%
import calc
calc.multiply(4,4)
# Out:
# 16

# %%
import calc
calc.subtract(3,1)
# Out:
# 2

# %%
import calc
calc.divide(10, 5)
# Out:
# 2.0

# %%
from calc import *

# %%
import calc as cc
cc.add(4,4)
# Out:
# 8

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
import random
random.randint(1, 10)
# Out:
# 4

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 8, 10, 10, 46, 44, 974554)

# %%
import os
os.getcwd()
# Out:
# 'c:\\study\\python-basic'

# %%
import sys
sys.version
# Out:
# '3.13.15 (tags/v3.13.15:4061bc4, Aug  5 2026, 13:05:39) [MSC v.1944 64 bit (AMD64)]'

# %%
import time
time.sleep(1)

# %% [markdown]
# # 라이브러리 가져오기
# 1. pip install # pip : 파이썬의 패키지 관리자, install : 다운로드한 다음 풀어준다.
# 2. import 라이브러리

# %%
import requests

# %%
requests.get("https://www.google.com")
# Out:
# <Response [200]>

# %% [markdown]
# # 판다스 pandas 라이브러리 사용하기
# (python -m) pip install pandas

# %%
#라이브러리 호출
import pandas as pd

#표로 보기 위한 원시 데이터(딕셔너리)
data = {
    '이름': ['김철수', '이영희', '박민수', '정수진', '최영호', '한미래', '윤지원'],
    '나이': [25, 28, 22, 31, 27, 24, 29],
    '점수': [85, 92, 78, 95, 88, 73, 91]
}

# %%
# 판다스의 데이터프레임객체 생성
df = pd.DataFrame(data)
# 상위 5개 데이터 조회
df.head()
# Out:
#     이름  나이  점수
# 0  김철수  25  85
# 1  이영희  28  92
# 2  박민수  22  78
# 3  정수진  31  95
# 4  최영호  27  88

# %%
pd.DataFrame(data).head()
# Out:
#     이름  나이  점수
# 0  김철수  25  85
# 1  이영희  28  92
# 2  박민수  22  78
# 3  정수진  31  95
# 4  최영호  27  88

# %%
# df 의 나이 속성의 평균을 구하세요
age_mean = int(df['나이'].mean())
age_mean
# Out:
# 26

# %%
round(int(df['나이'].mean()))
# Out:
# 26

# %%
df.describe()
# Out:
#               나이         점수
# count   7.000000   7.000000
# mean   26.571429  86.000000
# std     3.101459   7.958224
# min    22.000000  73.000000
# 25%    24.500000  81.500000
# 50%    27.000000  88.000000
# 75%    28.500000  91.500000
# max    31.000000  95.000000

# %% [markdown]
# # 패키지
#
# 모듈의 집합 > 디렉토리(폴더)로 묶어준다

# %% [markdown]
# 모듈을 호출하는 코드 : C:\study\python-basic\my_first_package\main.app.py
# 모듈은 패키지 magic_calc 에 포함 :
# C:\study\python-basic\my_first_package\magic_calc\basic_ops.py
# C:\study\python-basic\my_first_package\magic_calc\advanced_ops.py
