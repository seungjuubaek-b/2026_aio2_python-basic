# %%
print("hello!!!")
print("반갑습니다")
print("안녕히 가세요~")
# Out:
# hello!!!
# 반갑습니다
# 안녕히 가세요~

# %%
print("Hello Python Programming...!")
# Out:
# Hello Python Programming...!

# %%
print(5+2)
# Out:
# 7

# %%
print(273)
# Out:
# 273

# %%
print(52, 273, "Hello")
# Out:
# 52 273 Hello

# %%
print("안녕하세요", "저의 이름은", "백승주입니다.")
# Out:
# 안녕하세요 저의 이름은 백승주입니다.
